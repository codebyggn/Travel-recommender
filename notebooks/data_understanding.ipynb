# %%
import pandas as pd
import json
from pathlib import Path

# %%
json_path = Path("../data/raw/dataset1/india_tourism_dataset.json")

print(json_path.exists())
print(json_path)
# Out:
# True
# ..\data\raw\dataset1\india_tourism_dataset.json

# %%
with open(json_path, "r", encoding="utf-8") as file:
    tourism_data = json.load(file)

print(type(tourism_data))
# Out:
# <class 'list'>

# %%
print(len(tourism_data))
# Out:
# 100

# %%
print(type(tourism_data[0]))
# Out:
# <class 'dict'>

# %%
print(tourism_data[0])
# Out:
# {'id': 1, 'state': 'Goa', 'district': 'North Goa, South Goa', 'region': 'West India', 'coordinates': {'latitude': 15.3, 'longitude': 73.8}, 'altitude_m': 50, 'popularity_score': 9, 'accessibility': 'Easy', 'nearest_airport': {'name': 'Dabolim Airport', 'distance_km': 22}, 'nearest_railway_station': {'name': 'Margao Railway Station', 'distance_km': 35}, 'nearest_major_city': {'name': 'Bengaluru', 'distance_km': 600}, 'road_connectivity': 'Excellent', 'budget_category': {'accommodation_range': [800, 1500], 'food_range': [300, 600], 'activities_range': [200, 500], 'local_transport_range': [100, 200], 'total_daily_range': [1400, 2800]}, 'mid_range_category': {'accommodation_range': [2000, 4000], 'food_range': [600, 1200], 'activities_range': [500, 1000], 'local_transport_range': [200, 400], 'total_daily_range': [3300, 6600]}, 'luxury_category': {'accommodation_range': [8000, 20000], 'food_range': [1500, 3000], 'activities_range': [1000, 2500], 'local_transport_range': [300, 600], 'total_
# ...

# %%
print(tourism_data[0].keys())
# Out:
# dict_keys(['id', 'state', 'district', 'region', 'coordinates', 'altitude_m', 'popularity_score', 'accessibility', 'nearest_airport', 'nearest_railway_station', 'nearest_major_city', 'road_connectivity', 'budget_category', 'mid_range_category', 'luxury_category', 'trip_types', 'primary_attractions', 'activities_available', 'unique_experiences', 'hidden_gems', 'best_seasons', 'avoid_seasons', 'peak_tourist_season', 'off_season', 'average_temperature', 'rainfall_pattern', 'ideal_for', 'ideal_for_why', 'special_considerations', 'minimum_days', 'ideal_days', 'maximum_days', 'suggested_itinerary', 'accommodation_types', 'food_scene', 'safety_rating', 'safety_notes', 'internet_connectivity', 'mobile_network', 'atm_availability', 'language_spoken', 'permits_required', 'local_culture', 'festivals_events', 'local_customs', 'shopping_highlights', 'local_cuisine_must_try', 'last_updated', 'data_sources', 'user_reviews_summary', 'recent_developments', 'sustainability_notes', 'destination_name', '
# ...
